# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("data/from_scratch_double_gravity_InvertedPendulum-v5_episode_100.csv")
df2 = pd.read_csv("data/reload_double_gravity_InvertedPendulum-v5_episode_100.csv")

plt.plot(df1["episode"], df1["total_reward"], label="from_scratch_double_gravity")
plt.plot(df2["episode"], df2["total_reward"], label="reload_double_gravity")
plt.legend()
plt.show()
